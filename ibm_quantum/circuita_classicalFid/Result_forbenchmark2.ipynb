# %% [markdown]
# ## Results

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-color:#aaa;border-spacing:0;}
# .tg td{background-color:#fff;border-color:#aaa;border-style:solid;border-width:1px;color:#333;
#   font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{background-color:#f38630;border-color:#aaa;border-style:solid;border-width:1px;color:#fff;
#   font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-g30d{background-color:#FCFBE3;border-color:inherit;text-align:center;vertical-align:top}
# .tg .tg-c3ow{border-color:inherit;text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-c3ow">backend</th>
#     <th class="tg-c3ow">qubits</th>
#     <th class="tg-c3ow">CF</th>
#     <th class="tg-c3ow">mitigated CF</th>
#     <th class="tg-c3ow">shots<br></th>
#     <th class="tg-c3ow">date</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-g30d" rowspan="8">Casablanca</td>
#     <td class="tg-g30d">0-1-3-5</td>
#     <td class="tg-g30d">0.5687</td>
#     <td class="tg-g30d">0.5581</td>
#     <td class="tg-g30d" rowspan="24">8192</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">2-1-3-5</td>
#     <td class="tg-c3ow">0.5576</td>
#     <td class="tg-c3ow">0.5507</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">1-3-5-4</td>
#     <td class="tg-g30d">0.5839</td>
#     <td class="tg-g30d">0.3548</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">1-3-5-6</td>
#     <td class="tg-c3ow">0.5537</td>
#     <td class="tg-c3ow">0.3438</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">5-3-1-0</td>
#     <td class="tg-g30d">0.5533</td>
#     <td class="tg-g30d">0.3957</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">5-3-1-2</td>
#     <td class="tg-c3ow">0.5595</td>
#     <td class="tg-c3ow">0.3984</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">4-5-3-1</td>
#     <td class="tg-g30d">0.5830</td>
#     <td class="tg-g30d">0.5487</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">6-5-3-1</td>
#     <td class="tg-c3ow">0.5943</td>
#     <td class="tg-c3ow">0.4524</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d" rowspan="4">Santiago</td>
#     <td class="tg-g30d">0-1-2-3</td>
#     <td class="tg-g30d">0.9225</td>
#     <td class="tg-g30d">0.9498</td>
#     <td class="tg-g30d">2021.04.25</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">1-2-3-4</td>
#     <td class="tg-c3ow">0.9220</td>
#     <td class="tg-c3ow">0.9488</td>
#     <td class="tg-c3ow">2021.04.25</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">3-2-1-0</td>
#     <td class="tg-g30d">0.8715</td>
#     <td class="tg-g30d">0.9276</td>
#     <td class="tg-g30d">2021.04.25</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">4-3-2-1</td>
#     <td class="tg-c3ow">0.9128</td>
#     <td class="tg-c3ow">0.9378</td>
#     <td class="tg-c3ow">2021.04.25</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d" rowspan="4">Athens</td>
#     <td class="tg-g30d">0-1-2-3</td>
#     <td class="tg-g30d">0.8852</td>
#     <td class="tg-g30d">0.9149</td>
#     <td class="tg-g30d">2021.04.23</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">1-2-3-4</td>
#     <td class="tg-c3ow">0.8972</td>
#     <td class="tg-c3ow">0.9278</td>
#     <td class="tg-c3ow">2021.04.23</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">3-2-1-0</td>
#     <td class="tg-g30d">0.8767</td>
#     <td class="tg-g30d">0.9071</td>
#     <td class="tg-g30d">2021.04.23</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">4-3-2-1</td>
#     <td class="tg-c3ow">0.8958</td>
#     <td class="tg-c3ow">0.9259</td>
#     <td class="tg-c3ow">2021.04.23</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d" rowspan="4">Bogota</td>
#     <td class="tg-g30d">0-1-2-3</td>
#     <td class="tg-g30d">0.8698</td>
#     <td class="tg-g30d">0.9402</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">1-2-3-4</td>
#     <td class="tg-c3ow">0.8557</td>
#     <td class="tg-c3ow">0.9388</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">3-2-1-0</td>
#     <td class="tg-g30d">0.8309</td>
#     <td class="tg-g30d">0.8893</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">4-3-2-1</td>
#     <td class="tg-c3ow">0.8541</td>
#     <td class="tg-c3ow">0.9139</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d" rowspan="4">Rome</td>
#     <td class="tg-g30d">0-1-2-3</td>
#     <td class="tg-g30d">0.7967</td>
#     <td class="tg-g30d">0.8428</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">1-2-3-4</td>
#     <td class="tg-c3ow">0.8430</td>
#     <td class="tg-c3ow">0.8886</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">3-2-1-0</td>
#     <td class="tg-g30d">0.7437</td>
#     <td class="tg-g30d">0.7771</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">4-3-2-1</td>
#     <td class="tg-c3ow">0.8015</td>
#     <td class="tg-c3ow">0.8416</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
# </tbody>
# </table>
