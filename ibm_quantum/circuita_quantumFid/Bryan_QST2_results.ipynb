# %% [markdown]
# ## Results

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-color:#aaa;border-spacing:0;}
# .tg td{background-color:#fff;border-color:#aaa;border-style:solid;border-width:1px;color:#333;
#   font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{background-color:#f38630;border-color:#aaa;border-style:solid;border-width:1px;color:#fff;
#   font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-g30d{background-color:#FCFBE3;border-color:inherit;text-align:center;vertical-align:top}
# .tg .tg-c3ow{border-color:inherit;text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-c3ow">backend</th>
#     <th class="tg-c3ow">qubits</th>
#     <th class="tg-c3ow">SF</th>
#     <th class="tg-c3ow">mitigated SF</th>
#     <th class="tg-c3ow">shots<br></th>
#     <th class="tg-c3ow">date</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-g30d" rowspan="8">Casablanca</td>
#     <td class="tg-g30d">0-1-3-5</td>
#     <td class="tg-g30d">0.1812</td>
#     <td class="tg-g30d">0.2071</td>
#     <td class="tg-g30d" rowspan="24">8192</td>
#     <td class="tg-g30d">2021.04.28</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">2-1-3-5</td>
#     <td class="tg-c3ow">0.1963</td>
#     <td class="tg-c3ow">0.2166</td>
#     <td class="tg-c3ow">2021.04.28</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">1-3-5-4</td>
#     <td class="tg-g30d">0.3182</td>
#     <td class="tg-g30d">0.3436</td>
#     <td class="tg-g30d">2021.04.28</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">1-3-5-6</td>
#     <td class="tg-c3ow">0.1118</td>
#     <td class="tg-c3ow">0.1105</td>
#     <td class="tg-c3ow">2021.04.28</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">5-3-1-0</td>
#     <td class="tg-g30d">0.5006</td>
#     <td class="tg-g30d">0.5527</td>
#     <td class="tg-g30d">2021.04.28</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">5-3-1-2</td>
#     <td class="tg-c3ow">0.3726</td>
#     <td class="tg-c3ow">0.4141</td>
#     <td class="tg-c3ow">2021.04.28</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">4-5-3-1</td>
#     <td class="tg-g30d">0.1701</td>
#     <td class="tg-g30d">0.1818</td>
#     <td class="tg-g30d">2021.04.28</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">6-5-3-1</td>
#     <td class="tg-c3ow">0.1301</td>
#     <td class="tg-c3ow">0.1324</td>
#     <td class="tg-c3ow">2021.04.28</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d" rowspan="4">Santiago</td>
#     <td class="tg-g30d">0-1-2-3</td>
#     <td class="tg-g30d">0.7435</td>
#     <td class="tg-g30d">0.8116</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">1-2-3-4</td>
#     <td class="tg-c3ow">0.7221</td>
#     <td class="tg-c3ow">0.8011</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">3-2-1-0</td>
#     <td class="tg-g30d">0.5431</td>
#     <td class="tg-g30d">0.5939</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">4-3-2-1</td>
#     <td class="tg-c3ow">0.6659</td>
#     <td class="tg-c3ow">0.7803</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d" rowspan="4">Athens</td>
#     <td class="tg-g30d">0-1-2-3</td>
#     <td class="tg-g30d">0.6632</td>
#     <td class="tg-g30d">0.7311</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">1-2-3-4</td>
#     <td class="tg-c3ow">0.6652</td>
#     <td class="tg-c3ow">0.7868</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">3-2-1-0</td>
#     <td class="tg-g30d">0.5599</td>
#     <td class="tg-g30d">0.6283</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">4-3-2-1</td>
#     <td class="tg-c3ow">0.6847</td>
#     <td class="tg-c3ow">0.7811</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d" rowspan="4">Bogota</td>
#     <td class="tg-g30d">0-1-2-3</td>
#     <td class="tg-g30d">0.4710</td>
#     <td class="tg-g30d">0.6022</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">1-2-3-4</td>
#     <td class="tg-c3ow">0.5278</td>
#     <td class="tg-c3ow">0.7802</td>
#     <td class="tg-c3ow">2021.04.27</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">3-2-1-0</td>
#     <td class="tg-g30d">0.4998</td>
#     <td class="tg-g30d">0.6512</td>
#     <td class="tg-g30d">2021.04.27</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">4-3-2-1</td>
#     <td class="tg-c3ow">0.4003</td>
#     <td class="tg-c3ow">0.6269</td>
#     <td class="tg-c3ow">2021.04.27</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d" rowspan="4">Rome</td>
#     <td class="tg-g30d">0-1-2-3</td>
#     <td class="tg-g30d">0.3893</td>
#     <td class="tg-g30d">0.4727</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">1-2-3-4</td>
#     <td class="tg-c3ow">0.5587</td>
#     <td class="tg-c3ow">0.6827</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-g30d">3-2-1-0</td>
#     <td class="tg-g30d">0.1537</td>
#     <td class="tg-g30d">0.1734</td>
#     <td class="tg-g30d">2021.04.26</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">4-3-2-1</td>
#     <td class="tg-c3ow">0.3775</td>
#     <td class="tg-c3ow">0.4475</td>
#     <td class="tg-c3ow">2021.04.26</td>
#   </tr>
# </tbody>
# </table>
